# %%
# %run frft.py
import numpy as np
import matplotlib.pyplot as plt

# %%
N = 2500
x = np.zeros(N)
x[int(N/2)-int(N/8):int(N/2)+int(N/8)] = 0.1
X = FrFFT(x,2*np.pi)

# %%
plt.plot(numpy.abs(X.result))
plt.show()

# %%
np.abs(X.result)
# Out:
# array([  6.24000000e+01,   1.60751082e-09,   6.24000000e+01, ...,
#          1.09016124e-09,   6.24000000e+01,   1.07293572e-09])

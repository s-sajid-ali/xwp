# %% [markdown]
# ## Wigner function
#
# Wigner distribution function gives the phase space distribution of a function. <br>
# The definition is as follows, as per Advances in Optics and Photonics 3, 272–365 (2011) : <br><br>
#
# $W_{f}(p,q) = \left(\dfrac{|K|}{2\pi}\right)^{N}\int f^{*}\left(q-\dfrac{q^{'}}{2}\right) f\left(q+\dfrac{q^{'}}{2}\right)exp(-iKq^{'}.p)d^{N}q^{'}$

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import gaussian
import quadpy

# %%
f =gaussian(100,10)
plt.plot(f)
plt.show()
